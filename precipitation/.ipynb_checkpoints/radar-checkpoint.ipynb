# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['lines.linewidth'] = 3
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['legend.fontsize'] = 15
os.chdir('/raid/jiawei/precipitation/data/radar/stage_4')

# %%
def plot_ts(data_pnw,data_satellite,ofile):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    ax.plot(np.arange(1,13),data_pnw,'k-',label='Drought monitor')
    ax.plot(np.arange(1,13),data_satellite,'b-',label='Stage 4')
    ax.set_xlabel('Month')
    ax.set_ylabel('Precipitation (inch/day)')
    ax.legend(loc='upper center')
    fig.savefig(ofile,dpi=300)

# %%
def plot_ts_3(data_pnw,data_level,data_stage,ofile):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    ax.plot(np.arange(1,13),data_pnw,'k-',label='Drought monitor')
    ax.plot(np.arange(1,13),data_level,'b-',label='Level 3')
    ax.plot(np.arange(1,13),data_stage,'r-',label='Stage 4')
    ax.set_xlabel('Month')
    ax.set_ylabel('Precipitation (inch/day)')
    ax.legend(loc='upper center')
    fig.savefig(ofile,dpi=300)

# %%
def get_prcp(prcp_data):
    total_length = lat_data.shape[0]*lat_data.shape[1]
    lat_tmp = lat_data.reshape(total_length,1)
    lon_tmp = lon_data.reshape(total_length,1)
    prcp_tmp = prcp_data.reshape(total_length,1)
    count=0
    for i in np.arange(total_length):
        if 0<prcp_tmp[i,0]<10000:
            count = count+1    
    lats = np.random.rand(count,1)
    lons = np.random.rand(count,1)
    prcp = np.random.rand(count,1)
    ii=0
    for i in np.arange(total_length):
        if 0<prcp_tmp[i,0]<100000:
            lats[ii] = lat_tmp[i,0]
            lons[ii] = lon_tmp[i,0]*-1
            prcp[ii] = prcp_tmp[i,0]
            ii = ii +1
    return prcp

# %%
def get_mean(prcp):
    lat_basin = np.genfromtxt('lat.txt')
    lon_basin = np.genfromtxt('lon.txt')
    index = []
    prcp_basin = []
    size = lats.size
    size_basin = lat_basin.size
    for i in np.arange(size_basin):
        for j in np.arange(size):
            if lats[j,0] == lat_basin[i] and lons[j,0] == lon_basin[i]:
#                print j,prcp[j]
                index.append(j)
                prcp_basin.append(prcp[j])
    prcp_daily_mean = np.sum(prcp_basin)*39.3701/(1000*np.size(prcp_basin))    ## daily mean precipitation for basin (inch/day)
#    print prcp_basin
    print 'daily mean',prcp_daily_mean

# %% [markdown]
# ##storm

# %%
data_pnw = np.genfromtxt('pnw_monthly_mean.txt')
data_satellite = np.genfromtxt('stage_4_monthly_mean_storm.txt')
ofile = 'stage_4_monthly_mean_storm.png'
plot_ts(data_pnw,data_satellite,ofile)
print np.mean(data_pnw),np.mean(data_satellite)

# %%
data_pnw = np.genfromtxt('pnw_monthly_mean.txt')
data_stage = np.genfromtxt('stage_4_monthly_mean_storm.txt')
data_level = np.genfromtxt('level3_monthly_mean.txt')
ofile = 'monthly_mean_storm.png'
plot_ts_3(data_pnw,data_level,data_stage,ofile)
print np.mean(data_pnw),np.mean(data_stage),np.mean(data_level)
# Out:
# 0.16662475 0.0878939167718 0.08329625

# %% [markdown]
# ##no storm

# %%
data_pnw = np.genfromtxt('pnw_monthly_mean_no_storm.txt')
data_satellite = np.genfromtxt('stage_4_monthly_mean_no_storm.txt')
ofile = 'stage_4_monthly_mean_no_storm.png'
plot_ts(data_pnw,data_satellite,ofile)

# %%
data_pnw = np.genfromtxt('pnw_monthly_mean_no_storm.txt')
data_stage = np.genfromtxt('stage_4_monthly_mean_no_storm.txt')
data_level = np.genfromtxt('level3_monthly_mean_no_storm.txt')
ofile = 'monthly_mean_no_storm.png'   
plot_ts_3(data_pnw,data_level,data_stage,ofile)
print np.mean(data_pnw),np.mean(data_stage),np.mean(data_level)
# Out:
# 0.0880459166667 0.0301965790151 0.077241

# %% [raw]
# '''lat_basin,lon_basin are coordinates of basin'''
# lat_basin = np.genfromtxt('data.txt',skiprows=1,usecols=0)
# lon_basin = np.genfromtxt('data.txt',skiprows=1,usecols=1)
# index = np.genfromtxt('data.txt',skiprows=1,usecols=2)
# prcp_basin = np.genfromtxt('data.txt',skiprows=1,usecols=3)
# index = np.int0(index)

# %%
lat_file = '/nfs/flouric/raid/xiaodong.chen/class/cee599_precp/tools/lat.txt'
lon_file = '/nfs/flouric/raid/xiaodong.chen/class/cee599_precp/tools/lon.txt'
lat_data = np.genfromtxt(lat_file)
lon_data = np.genfromtxt(lon_file)

# %%
def get_prcp_storm(prcp_data):
    total_length = lat_data.shape[0]*lat_data.shape[1]
    lat_tmp = lat_data.reshape(total_length,1)
    lon_tmp = lon_data.reshape(total_length,1)
    prcp_tmp = prcp_data.reshape(total_length,1)
    count=0
    for i in np.arange(total_length):
        if 0<prcp_tmp[i,0]<10000:
            count = count+1    
    lats = np.random.rand(count,1)
    lons = np.random.rand(count,1)
    prcp = np.random.rand(count,1)
    ii=0
    for i in np.arange(total_length):
        if 0<prcp_tmp[i,0]<12.7:
            lats[ii] = lat_tmp[i,0]
            lons[ii] = lon_tmp[i,0]*-1
            prcp[ii] = prcp_tmp[i,0]
            ii = ii +1
    return prcp

# %% [markdown]
# ##daily

# %% [markdown]
# ### storm exists

# %%
'''prcp_data are daily mean precipitation for whole U.S. (kg/m-2)'''

infile = '/raid/jiawei/precipitation/data/radar/stage_4/daily_mean.nc'
rootgroup = nc.Dataset(infile,'r',format='NETCDF4')
prcp_data = rootgroup.variables['Total_precipitation_surface_24_Hour_Accumulation'][:]
rootgroup.close()

prcp = get_prcp(prcp_data)
get_mean(prcp)
# Out:
# [array([ 3.35984945]), array([ 3.38902044]), array([ 3.55468249]), array([ 3.74919271]), array([ 4.06975269]), array([ 4.22432709]), array([ 4.66878366]), array([ 3.29903126]), array([ 3.32712603]), array([ 3.5580194]), array([ 3.89838552]), array([ 4.26684618]), array([ 4.71571589]), array([ 5.14520979]), array([ 5.77631855]), array([ 3.49903131]), array([ 3.66889143]), array([ 3.9931109]), array([ 4.6600647]), array([ 5.18665218]), array([ 5.670506])]
# daily mean 0.16438051185

# %% [markdown]
# ###remove storm (0.5 inch/day)

# %%
'''prcp_data are daily mean precipitation for whole U.S. (kg/m-2)'''

infile = '/raid/jiawei/precipitation/data/radar/stage_4/daily_mean_no_storm.nc'
rootgroup = nc.Dataset(infile,'r',format='NETCDF4')
prcp_data = rootgroup.variables['Total_precipitation_surface_24_Hour_Accumulation'][:]
rootgroup.close()
prcp = get_prcp(prcp_data)
get_mean(prcp)
# Out:
# [array([ 1.77042258]), array([ 1.73730814]), array([ 1.71935487]), array([ 1.77671075]), array([ 1.88934624]), array([ 1.875]), array([ 1.92589843]), array([ 1.72157097]), array([ 1.71988237]), array([ 1.71121716]), array([ 1.78407717]), array([ 1.90060759]), array([ 1.96827161]), array([ 1.91767681]), array([ 1.84786546]), array([ 1.72813237]), array([ 1.76928568]), array([ 1.73878789]), array([ 1.93914115]), array([ 1.90542245]), array([ 1.92374837])]
# daily mean 0.0717468105178

# %% [markdown]
# ##monthly

# %% [markdown]
# ### storm exists

# %%
infile = '/raid/jiawei/precipitation/data/radar/stage_4/monthly_mean.nc'
rootgroup = nc.Dataset(infile,'r',format='NETCDF4')
prcp_data = rootgroup.variables['Total_precipitation_surface_24_Hour_Accumulation'][:]
rootgroup.close()
for i in np.arange(12):
    prcp = get_prcp(prcp_data[i])
    get_mean(prcp)
# Out:
# [array([ 2.07349396]), array([ 2.02048206]), array([ 2.16506028]), array([ 1.99277115]), array([ 1.85060239]), array([ 1.82409644]), array([ 1.91686749]), array([ 1.6710844]), array([ 1.70361447]), array([ 1.86626506]), array([ 1.85180724]), array([ 1.93855429]), array([ 2.04578328]), array([ 2.70481944]), array([ 3.91566277]), array([ 2.01566267]), array([ 2.3096385]), array([ 2.86024094]), array([ 3.09638572]), array([ 3.53132534]), array([ 4.55903625])]
# daily mean 0.0935757050899
# [array([ 0.57419354]), array([ 0.58817208]), array([ 0.60215056]), array([ 0.64301074]), array([ 0.67849463]), array([ 0.67311829]), array([ 0.65376347]), array([ 0.64301074]), array([ 0.66236562]), array([ 0.65698928]), array([ 0.6763441]), array([ 0.67526883]), array([ 0.67526883]), array([ 0.73010755]), array([ 0.74301076]), array([ 0.71935487]), array([ 0.73870969]), array([ 0.74731183]), array([ 0.80860215]), array([ 0.80322582]), array([ 0.84086025])]
# daily mean 0.027246609388
# [array([ 1.72555566]), array([ 1.79555559]), array([ 1.80777776]), array([ 6.91363621]), array([ 7.3034091]), array([ 7.44204569]), array([ 8.37954521]), array([ 1.72777784]), array([ 1.75333333]), array([ 1.85333335]), array([ 7.88863659]), array([ 8.05909061]), array([ 8.49659061]), array([ 8.83295441]), array([ 9.05795479]), array([ 1.87555563]), array([ 8.18409061]), array([ 8.27499962]), array([ 8.41363621]), array([ 8.64659119]), array([ 8.92613697])]
# daily mean 0.238766921186
# [array([ 0.86344087]), array([ 0.76774192]), array([ 0.64193553]), array([ 0.5387097]), array([ 0.50537634]), array([ 0.47956991]), array([ 0.45913979]), array([ 0.53440863]), array([ 0.48709679]), array([ 0.47526884]), array([ 0.44946238]), array([ 0.44301075]), array([ 0.43440861]), array([ 0.43440861]), array([ 0.41827956]), array([ 0.42688173]), array([ 0.41075268]), array([ 0.40537634]), array([ 0.40967742]), array([ 0.44516131]), array([ 0.44086021])]
# daily mean 0.0196306216216
# [array([ 0.40752688]), array([ 0.39247313]), array([ 0.37956989]), array([ 0.37956992]), array([ 0.355914]), array([ 0.34516129]), array([ 0.34193549]), array([ 0.36129034]), array([ 0.34623656]), array([ 0.35698926]), array([ 0.36451614]), array([ 0.31182796]), array([ 0.35161293]), array([ 0.32903227]), array([ 0.30215055]), array([ 0.34946239]), array([ 0.35376346]), array([ 0.31827956]), array([ 0.32580647]), array([ 0.37311828]), array([ 0.35483873])]
# daily mean 0.0138752896118
# [array([ 3.47058821]), array([ 3.22470593]), array([ 3.09058833]), array([ 2.74588227]), array([ 2.24823523]), array([ 1.92117655]), array([ 1.65176475]), array([ 3.09764719]), array([ 2.67176485]), array([ 2.28117657]), array([ 1.63411772]), array([ 0.73411769]), array([ 0.57882357]), array([ 0.67647058]), array([ 0.61647058]), array([ 0.56823528]), array([ 0.66588235]), array([ 0.72000003]), array([ 0.64352942]), array([ 0.5894118]), array([ 0.5411765])]
# daily mean 0.0644390399998
# [array([ 0.75268817]), array([ 0.73118281]), array([ 0.70752692]), array([ 0.70107526]), array([ 0.68172044]), array([ 0.66774195]), array([ 0.67311829]), array([ 0.66559142]), array([ 0.65591401]), array([ 0.65806454]), array([ 0.69032258]), array([ 0.70537633]), array([ 0.69354838]), array([ 0.69999999]), array([ 0.69569892]), array([ 0.67311829]), array([ 0.70430106]), array([ 0.7182796]), array([ 0.66666669]), array([ 0.70215052]), array([ 0.66989249])]
# daily mean 0.0272103233927
# [array([ 2.00166678]), array([ 1.93833339]), array([ 1.93666673]), array([ 1.89666665]), array([ 1.93833339]), array([ 1.88]), array([ 1.76666665]), array([ 2.48833346]), array([ 2.58666682]), array([ 2.67666674]), array([ 2.61000013]), array([ 2.70833349]), array([ 2.70499992]), array([ 7.74833345]), array([ 7.95833349]), array([ 3.28999996]), array([ 2.64333344]), array([ 2.42166662]), array([ 1.9083333]), array([ 1.39999998]), array([ 1.46833336])]
# daily mean 0.10868335034
# [array([ 3.49193549]), array([ 3.54838705]), array([ 3.57903242]), array([ 3.6500001]), array([ 3.8467741]), array([ 3.82258081]), array([ 3.87741947]), array([ 3.62903237]), array([ 3.59677434]), array([ 3.13709688]), array([ 3.76290321]), array([ 3.97096777]), array([ 3.4080646]), array([ 2.73709679]), array([ 2.86612916]), array([ 2.63064528]), array([ 2.66129041]), array([ 2.62258077]), array([ 2.53870964]), array([ 2.45161295]), array([ 2.39032269])]
# daily mean 0.12789537521
# [array([ 9.79833317]), array([ 10.69333363]), array([ 9.32333374]), array([ 7.14166689]), array([ 6.771667]), array([ 4.55500031]), array([ 5.32500029]), array([ 3.1474576]), array([ 3.03050852]), array([ 3.37118649]), array([ 3.10169506]), array([ 3.20847464]), array([ 3.05084753]), array([ 2.7525425]), array([ 3.47627115]), array([ 0.73559326]), array([ 0.64406782]), array([ 0.59491527]), array([ 0.53728813]), array([ 0.52033901]), array([ 0.49322036])]
# daily mean 0.154242194953
# [array([ 2.45645165]), array([ 2.85322595]), array([ 3.10483885]), array([ 3.10000014]), array([ 3.45483875]), array([ 2.80161285]), array([ 2.79032254]), array([ 3.18064523]), array([ 3.01774192]), array([ 2.69032264]), array([ 2.94516134]), array([ 2.98387098]), array([ 3.01451612]), array([ 3.4000001]), array([ 3.29193568]), array([ 2.11451626]), array([ 1.87258065]), array([ 1.96935487]), array([ 2.11129022]), array([ 1.81935489]), array([ 1.59516132])]
# daily mean 0.10605131888
# [array([ 1.71612906]), array([ 1.59354842]), array([ 1.50645161]), array([ 1.36129034]), array([ 1.18225801]), array([ 1.32096779]), array([ 1.36935484]), array([ 1.15967739]), array([ 1.09677422]), array([ 1.10806453]), array([ 1.06129038]), array([ 1.02419353]), array([ 1.05161297]), array([ 1.01451612]), array([ 1.14999998]), array([ 1.4064517]), array([ 1.5806452]), array([ 1.80967736]), array([ 1.81129038]), array([ 1.77258062]), array([ 2.02258062])]
# daily mean 0.0545919962635

# %% [markdown]
# ###remove storm events (0.5 inch/day)

# %%
infile = '/raid/jiawei/precipitation/data/radar/stage_4/monthly_mean_no_storm.nc'
rootgroup = nc.Dataset(infile,'r',format='NETCDF4')
prcp_data = rootgroup.variables['Total_precipitation_surface_24_Hour_Accumulation'][:]
rootgroup.close()
for i in np.arange(12):
    prcp = get_prcp(prcp_data[i])
    get_mean(prcp)
# Out:
# [array([ 0.37307695]), array([ 0.66374999]), array([ 0.66374999]), array([ 0.67530864]), array([ 0.64444447]), array([ 0.59506172]), array([ 0.46125001]), array([ 0.54556966]), array([ 0.51012659]), array([ 0.55124998]), array([ 0.505]), array([ 0.49375001]), array([ 0.49375001]), array([ 0.43000001]), array([ 0.46625]), array([ 0.50749999]), array([ 0.48750001]), array([ 0.49250001]), array([ 0.54750001]), array([ 0.46835443]), array([ 0.51265824])]
# daily mean 0.0207880703055
# [array([ 0.55000001]), array([ 0.54130435]), array([ 0.55108696]), array([ 0.56413043]), array([ 0.56086957]), array([ 0.55760872]), array([ 0.5402174]), array([ 0.55652177]), array([ 0.54891306]), array([ 0.68602151]), array([ 0.66881722]), array([ 0.66881722]), array([ 0.66989249]), array([ 0.66774195]), array([ 0.64408606]), array([ 0.64731181]), array([ 0.61935484]), array([ 0.62795699]), array([ 0.65483874]), array([ 0.69462365]), array([ 0.57391304])]
# daily mean 0.0239858168618
# [array([ 0.64555556]), array([ 0.63555557]), array([ 0.63777781]), array([ 0.60111111]), array([ 0.58777779]), array([ 0.59222221]), array([ 0.56999999]), array([ 0.61222225]), array([ 0.60111111]), array([ 0.58111113]), array([ 0.59111112]), array([ 0.59666669]), array([ 0.59000003]), array([ 0.59888887]), array([ 0.62333333]), array([ 0.60888892]), array([ 0.61666667]), array([ 0.61888891]), array([ 0.60000002]), array([ 0.59666669]), array([ 0.62555557])]
# daily mean 0.023867863296
# [array([ 0.5387097]), array([ 0.50537634]), array([ 0.47956991]), array([ 0.45913979]), array([ 0.44193548]), array([ 0.42903227]), array([ 0.42688173]), array([ 0.44946238]), array([ 0.44301075]), array([ 0.43440861]), array([ 0.43440861]), array([ 0.41827956]), array([ 0.40752688]), array([ 0.43870968]), array([ 0.42580646]), array([ 0.40967742]), array([ 0.44516131]), array([ 0.44086021]), array([ 0.43655914]), array([ 0.43010753]), array([ 0.4311828])]
# daily mean 0.017483711275
# [array([ 0.68172044]), array([ 0.68064517]), array([ 0.63978493]), array([ 0.63333333]), array([ 0.61290324]), array([ 0.60967743]), array([ 0.59677422]), array([ 0.62580645]), array([ 0.59462368]), array([ 0.57634407]), array([ 0.60107529]), array([ 0.58279568]), array([ 0.55376345]), array([ 0.56451613]), array([ 0.52795702]), array([ 0.54623657]), array([ 0.52473116]), array([ 0.50537634]), array([ 0.49032259]), array([ 0.4655914]), array([ 0.43870968])]
# daily mean 0.0225959782138
# [array([ 0.42142859]), array([ 0.42857143]), array([ 0.43214285]), array([ 0.44285715]), array([ 0.46666667]), array([ 0.47500002]), array([ 0.45476189]), array([ 0.46309525]), array([ 0.48571429]), array([ 0.48214287]), array([ 0.50357145]), array([ 0.50357145]), array([ 0.49404761]), array([ 0.48809525]), array([ 0.47023809]), array([ 0.5202381]), array([ 0.52380955]), array([ 0.50952381]), array([ 0.51190478]), array([ 0.48928571]), array([ 0.47619048])]
# daily mean 0.0188280140841
# [array([ 0.55913979]), array([ 0.75591397]), array([ 0.67500001]), array([ 0.56373626]), array([ 0.72173911]), array([ 0.63478261]), array([ 0.63152176]), array([ 0.67173916]), array([ 0.625]), array([ 0.61195654]), array([ 0.62934786]), array([ 0.64565217]), array([ 0.60326087]), array([ 0.57608694]), array([ 0.60000002]), array([ 0.63913041]), array([ 0.61195654]), array([ 0.59130436]), array([ 0.60543478]), array([ 0.62934786]), array([ 0.61413044])]
# daily mean 0.0247397611587
# [array([ 0.98333335]), array([ 0.9666667]), array([ 0.94833332]), array([ 1.02833331]), array([ 1.06666672]), array([ 1.02499998]), array([ 0.91333336]), array([ 1.7689656]), array([ 1.81206906]), array([ 1.93103456]), array([ 1.83859658]), array([ 1.86666667]), array([ 1.92413795]), array([ 2.11379313]), array([ 2.0448277]), array([ 1.23571432]), array([ 1.97777784]), array([ 2.19444442]), array([ 2.09074068]), array([ 2.36000013]), array([ 2.1833334])]
# daily mean 0.0642553192547
# [array([ 1.27868855]), array([ 1.06721318]), array([ 0.85081971]), array([ 1.01967216]), array([ 1.]), array([ 1.01967216]), array([ 1.00655746]), array([ 1.26833332]), array([ 1.28000009]), array([ 1.66500008]), array([ 1.58833337]), array([ 0.93278688]), array([ 0.96065575]), array([ 0.92786884]), array([ 0.94918036]), array([ 0.95762712]), array([ 0.96949154]), array([ 1.1885246]), array([ 1.0573771]), array([ 1.03709674]), array([ 0.97096777])]
# daily mean 0.0431118845018
# [array([ 1.85849059]), array([ 1.66153848]), array([ 1.83018875]), array([ 1.72500002]), array([ 1.46399999]), array([ 1.46000004]), array([ 1.5]), array([ 1.21249998]), array([ 1.46315789]), array([ 1.33928573]), array([ 1.00535715]), array([ 0.89642859]), array([ 0.96250004]), array([ 0.84545457]), array([ 0.84000003]), array([ 1.5696429]), array([ 1.56727278]), array([ 1.41090918]), array([ 1.59824562]), array([ 1.61724138]), array([ 1.64137936])]
# daily mean 0.0552467359843
# [array([ 0.30655739]), array([ 0.31311476]), array([ 0.31311476]), array([ 0.30983606]), array([ 0.30491805]), array([ 0.45000002]), array([ 0.42741936]), array([ 0.17540984]), array([ 0.18196721]), array([ 0.17704917]), array([ 0.16065574]), array([ 0.17704917]), array([ 0.1852459]), array([ 0.25409839]), array([ 0.28360656]), array([ 0.45000002]), array([ 0.46721312]), array([ 0.12711865]), array([ 0.14576271]), array([ 0.14406779]), array([ 0.28999999])]
# daily mean 0.0105815667867
# [array([ 0.87540984]), array([ 0.8967213]), array([ 0.83770496]), array([ 0.91639346]), array([ 0.90327871]), array([ 0.98064518]), array([ 0.94032258]), array([ 0.92459017]), array([ 0.85573769]), array([ 0.87540984]), array([ 1.01774192]), array([ 1.09677422]), array([ 1.12258065]), array([ 0.85081971]), array([ 0.95161295]), array([ 0.96612906]), array([ 0.95000005]), array([ 0.783871]), array([ 0.90322584]), array([ 0.95000005]), array([ 0.95161295])]
# daily mean 0.0366527796554

# %%
prec = np.genfromtxt('test.txt')
np.mean(prec)
# Out:
# 0.086350728828025011
